# %% [raw]
# 01) ***** K-Means Clustering groups similar data points into clusters without needing labeled data.
#             It is used to uncover hidden patterns when the goal is to organize data based on similarity.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\satyam_07\\Desktop\\Global_Air_Pollution_Data_2025_2026.csv")

# %%
df
# Out:
#                       Date                City  Latitude  Longitude  PM2.5  \
# 0      2025-10-19 00:00:00    Lahore, Pakistan   31.5497    74.3436  115.9
# 1      2025-10-19 01:00:00    Lahore, Pakistan   31.5497    74.3436  119.2
# 2      2025-10-19 02:00:00    Lahore, Pakistan   31.5497    74.3436  120.6
# 3      2025-10-19 03:00:00    Lahore, Pakistan   31.5497    74.3436  120.1
# 4      2025-10-19 04:00:00    Lahore, Pakistan   31.5497    74.3436  118.7
# ...                    ...                 ...       ...        ...    ...
# 17467  2026-01-17 19:00:00  Jakarta, Indonesia   -6.2088   106.8456   53.2
# 17468  2026-01-17 20:00:00  Jakarta, Indonesia   -6.2088   106.8456   57.4
# 17469  2026-01-17 21:00:00  Jakarta, Indonesia   -6.2088   106.8456   69.2
# 17470  2026-01-17 22:00:00  Jakarta, Indonesia   -6.2088   106.8456   79.2
# 17471  2026-01-17 23:00:00  Jakarta, Indonesia   -6.2088   106.8456   77.8
#
#         PM10    NO2   SO2      CO  Ozone  Aerosol_Optical_Depth  \
# ...

# %%
df = df.iloc[:, 4:12]

# %%
df
# Out:
#        PM2.5   PM10    NO2   SO2      CO  Ozone  Aerosol_Optical_Depth  \
# 0      115.9  116.9  166.7  35.1  2668.0    0.0                   0.19
# 1      119.2  120.1  160.4  34.3  2211.0    0.0                   0.20
# 2      120.6  121.5  153.7  33.3  1818.0    0.0                   0.22
# 3      120.1  121.1  148.0  32.5  1438.0    0.0                   0.24
# 4      118.7  119.7  141.8  31.5  1122.0    0.0                   0.26
# ...      ...    ...    ...   ...     ...    ...                    ...
# 17467   53.2   53.3   80.9  47.1  3868.0   23.0                   0.68
# 17468   57.4   57.6   85.2  52.2  3359.0   13.0                   0.57
# 17469   69.2   69.4   83.5  57.2  2286.0   10.0                   0.51
# 17470   79.2   79.2   80.1  59.0  1416.0    9.0                   0.50
# 17471   77.8   78.0   75.5  55.4  1050.0    8.0                   0.52
#
#                      AQI_Class
# 0                    Unhealthy
# 1                    Unhealthy
# ...

# %%
df.isnull().sum()
# Out:
# PM2.5                    0
# PM10                     0
# NO2                      0
# SO2                      0
# CO                       0
# Ozone                    0
# Aerosol_Optical_Depth    0
# AQI_Class                0
# dtype: int64

# %%
x = df[["PM2.5","PM10","NO2","SO2","CO","Ozone","Aerosol_Optical_Depth"]]

# %%
x
# Out:
#        PM2.5   PM10    NO2   SO2      CO  Ozone  Aerosol_Optical_Depth
# 0      115.9  116.9  166.7  35.1  2668.0    0.0                   0.19
# 1      119.2  120.1  160.4  34.3  2211.0    0.0                   0.20
# 2      120.6  121.5  153.7  33.3  1818.0    0.0                   0.22
# 3      120.1  121.1  148.0  32.5  1438.0    0.0                   0.24
# 4      118.7  119.7  141.8  31.5  1122.0    0.0                   0.26
# ...      ...    ...    ...   ...     ...    ...                    ...
# 17467   53.2   53.3   80.9  47.1  3868.0   23.0                   0.68
# 17468   57.4   57.6   85.2  52.2  3359.0   13.0                   0.57
# 17469   69.2   69.4   83.5  57.2  2286.0   10.0                   0.51
# 17470   79.2   79.2   80.1  59.0  1416.0    9.0                   0.50
# 17471   77.8   78.0   75.5  55.4  1050.0    8.0                   0.52
#
# [17472 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
# x_scaled = pd.DataFrame(
#     scaler.fit_transform(x),
#     columns=x.columns
# )

# %%
from sklearn.cluster import KMeans

# %%
wcss = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(x_scaled)
    wcss.append(kmeans.inertia_)
df["cluster"] = clusters

# %%
plt.plot(range(1,11), wcss, marker="o")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.title("Elbow Method")
plt.show()

# %%
df.head()
# Out:
#    PM2.5   PM10    NO2   SO2      CO  Ozone  Aerosol_Optical_Depth  AQI_Class  \
# 0  115.9  116.9  166.7  35.1  2668.0    0.0                   0.19  Unhealthy
# 1  119.2  120.1  160.4  34.3  2211.0    0.0                   0.20  Unhealthy
# 2  120.6  121.5  153.7  33.3  1818.0    0.0                   0.22  Unhealthy
# 3  120.1  121.1  148.0  32.5  1438.0    0.0                   0.24  Unhealthy
# 4  118.7  119.7  141.8  31.5  1122.0    0.0                   0.26  Unhealthy
#
#    cluster
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2

# %%
df["cluster"].value_counts()
# Out:
# cluster
# 1    7426
# 0    4031
# 4    2731
# 2    2713
# 3     571
# Name: count, dtype: int64

# %%
ct = pd.crosstab(df["cluster"], df["AQI_Class"])
ct
# Out:
# AQI_Class  Good  Hazardous  Moderate  Unhealthy  Unhealthy for Sensitive
# cluster
# 0             0         64       100       3326                      541
# 1          3967          0      2706        135                      618
# 2             0       1184         0       1524                        5
# 3             0        557         0         14                        0
# 4           247         19       842        994                      629

# %%
ct.plot(kind="bar")

import matplotlib.pyplot as plt
plt.xlabel("Cluster Number")
plt.ylabel("Number of Data Points")
plt.title("AQI Class Distribution in 5 Clusters")
plt.show()

# %%
ct.plot(kind="bar", stacked=True)

plt.xlabel("Cluster")
plt.ylabel("Count")
plt.title("Cluster vs AQI Class")
plt.show()

# %%
sns.heatmap(ct, annot=True, fmt="d")
plt.title("Cluster vs AQI Class Heatmap")
plt.show()
